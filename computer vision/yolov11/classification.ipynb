# %% [markdown]
# # With Image

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-cls.pt")

# Perform object detection on an image
results = model("../data/sunFlower.jpg", conf=0.5, )
results[0].show()
results[0].save()
# Out:
# image 1/1 /home/ahmedcr7/Programming/Python/AI/computer vision/yolov11/../data/sunFlower.jpg: 224x224 daisy 0.29, rapeseed 0.10, greenhouse 0.10, stone_wall 0.09, bee 0.05, 52.4ms
# Speed: 16.0ms preprocess, 52.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# 'results_sunFlower.jpg'

# %% [markdown]
# # With Video

# %%
import cv2
from ultralytics import YOLO

# Load the YOLO model
model = YOLO("yolo11n-cls.pt")

# Open the video file
# video_path = "../data/2.avi"
# cap = cv2.VideoCapture(video_path)

cap = cv2.VideoCapture(0)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-cls.pt to 'yolo11n-cls.pt'...
# 100%|██████████| 5.52M/5.52M [00:05<00:00, 1.12MB/s]
# 0: 224x224 nematode 0.27, digital_clock 0.10, spotlight 0.04, theater_curtain 0.02, jellyfish 0.02, 663.1ms
# Speed: 139.8ms preprocess, 663.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/ahmedcr7/.local/lib/python3.11/site-packages/cv2/qt/plugins"
# 0: 224x224 nematode 0.29, digital_clock 0.13, spotlight 0.05, theater_curtain 0.02, jellyfish 0.02, 45.9ms
# Speed: 23.5ms preprocess, 45.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nematode 0.34, digital_clock 0.13, spotlight 0.05, theater_curtain 0.02, jellyfish 0.02, 32.1ms
# Speed: 7.0ms preprocess, 32.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 nematode 0.29, digital_clock 0.23, spotlight 0.09, projector 0.03, jellyfish 0.02, 16.9ms
# Speed: 6.2ms preprocess, 16.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 lampshade 0.15, jellyfish 0.11, digital_clock 0.11, nematode 0.07, projector 0.05, 17.6ms
# Speed: 7.3ms preprocess, 17.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 jellyfish 0.31, electric_ray 0.16, stingray 0.07, snorkel 0.06, dugong 0.04, 21.6ms
# Speed: 7.7ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.21, stingray 0.08, dugong 0.08, jellyfish 0.06, snorkel 0.05, 17.4ms
# Speed: 6.8ms preprocess, 17.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.14, jellyfish 0.12, neck_brace 0.08, bathing_cap 0.06, dugong 0.06, 17.6ms
# Speed: 6.6ms preprocess, 17.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.32, jellyfish 0.15, stingray 0.09, dugong 0.04, neck_brace 0.02, 15.3ms
# Speed: 7.1ms preprocess, 15.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.21, jellyfish 0.11, dugong 0.09, stingray 0.08, sea_lion 0.06, 19.0ms
# Speed: 7.3ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.20, stingray 0.08, jellyfish 0.08, dugong 0.08, wreck 0.07, 22.0ms
# Speed: 6.2ms preprocess, 22.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.18, stingray 0.11, dugong 0.07, neck_brace 0.06, jellyfish 0.05, 53.2ms
# Speed: 27.4ms preprocess, 53.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.18, neck_brace 0.09, jellyfish 0.09, stingray 0.08, dugong 0.06, 58.3ms
# Speed: 23.8ms preprocess, 58.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 jellyfish 0.21, electric_ray 0.14, stingray 0.10, wreck 0.06, snorkel 0.04, 38.0ms
# Speed: 10.9ms preprocess, 38.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.12, stingray 0.10, neck_brace 0.09, dugong 0.08, jellyfish 0.06, 32.1ms
# Speed: 15.6ms preprocess, 32.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.15, jellyfish 0.08, stingray 0.08, neck_brace 0.08, dugong 0.05, 29.2ms
# Speed: 12.1ms preprocess, 29.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.11, jellyfish 0.09, neck_brace 0.08, stingray 0.07, wreck 0.06, 35.8ms
# Speed: 8.9ms preprocess, 35.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 jellyfish 0.16, electric_ray 0.10, neck_brace 0.09, stingray 0.06, shower_cap 0.03, 39.4ms
# Speed: 8.6ms preprocess, 39.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.12, snorkel 0.08, neck_brace 0.07, shower_cap 0.07, dugong 0.06, 66.6ms
# Speed: 10.0ms preprocess, 66.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.13, stingray 0.13, wreck 0.07, dugong 0.06, neck_brace 0.06, 40.6ms
# Speed: 13.8ms preprocess, 40.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.11, stingray 0.10, electric_ray 0.10, dugong 0.08, jellyfish 0.08, 23.6ms
# Speed: 175.5ms preprocess, 23.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.10, shower_cap 0.08, dugong 0.07, stingray 0.07, jellyfish 0.07, 24.5ms
# Speed: 11.9ms preprocess, 24.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.12, stingray 0.11, dugong 0.07, neck_brace 0.07, jellyfish 0.05, 32.9ms
# Speed: 10.7ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.10, dugong 0.07, jellyfish 0.06, stingray 0.06, shower_cap 0.05, 36.2ms
# Speed: 9.0ms preprocess, 36.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.23, stingray 0.14, dugong 0.10, jellyfish 0.07, wreck 0.06, 47.8ms
# Speed: 23.3ms preprocess, 47.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.22, electric_ray 0.12, stingray 0.12, wreck 0.08, sea_lion 0.03, 34.1ms
# Speed: 8.9ms preprocess, 34.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.22, dugong 0.10, stingray 0.09, neck_brace 0.05, wreck 0.05, 36.2ms
# Speed: 11.7ms preprocess, 36.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.15, electric_ray 0.14, stingray 0.07, wreck 0.07, snorkel 0.05, 31.9ms
# Speed: 12.6ms preprocess, 31.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.26, stingray 0.17, dugong 0.09, wreck 0.06, jellyfish 0.03, 39.6ms
# Speed: 11.5ms preprocess, 39.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.20, dugong 0.16, electric_ray 0.14, wreck 0.04, snorkel 0.03, 26.9ms
# Speed: 16.1ms preprocess, 26.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.20, dugong 0.18, stingray 0.11, jellyfish 0.05, wreck 0.04, 33.0ms
# Speed: 12.0ms preprocess, 33.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.19, dugong 0.14, electric_ray 0.13, wreck 0.08, snorkel 0.05, 31.8ms
# Speed: 12.2ms preprocess, 31.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.22, electric_ray 0.15, stingray 0.11, wreck 0.05, jellyfish 0.05, 28.7ms
# Speed: 24.5ms preprocess, 28.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.17, stingray 0.14, electric_ray 0.14, wreck 0.06, snorkel 0.05, 28.9ms
# Speed: 14.9ms preprocess, 28.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.19, stingray 0.17, dugong 0.14, wreck 0.06, snorkel 0.04, 38.2ms
# Speed: 10.3ms preprocess, 38.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.25, stingray 0.17, electric_ray 0.14, wreck 0.04, snorkel 0.03, 38.1ms
# Speed: 11.4ms preprocess, 38.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.16, electric_ray 0.13, stingray 0.07, wreck 0.05, snorkel 0.04, 226.8ms
# Speed: 11.6ms preprocess, 226.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.18, electric_ray 0.14, dugong 0.11, jellyfish 0.06, wreck 0.05, 39.3ms
# Speed: 13.0ms preprocess, 39.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.19, stingray 0.14, dugong 0.12, wreck 0.05, jellyfish 0.04, 27.1ms
# Speed: 12.5ms preprocess, 27.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.17, stingray 0.16, electric_ray 0.14, wreck 0.05, jellyfish 0.05, 36.4ms
# Speed: 44.2ms preprocess, 36.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.16, dugong 0.16, electric_ray 0.15, jellyfish 0.07, wreck 0.04, 33.2ms
# Speed: 11.0ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.20, stingray 0.19, electric_ray 0.17, jellyfish 0.04, wreck 0.04, 44.0ms
# Speed: 11.9ms preprocess, 44.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.19, stingray 0.17, dugong 0.11, jellyfish 0.05, wreck 0.04, 49.5ms
# Speed: 9.1ms preprocess, 49.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, dugong 0.11, electric_ray 0.11, snorkel 0.06, wreck 0.04, 51.4ms
# Speed: 11.2ms preprocess, 51.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.26, stingray 0.19, dugong 0.13, jellyfish 0.05, wreck 0.03, 31.7ms
# Speed: 106.9ms preprocess, 31.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.15, stingray 0.14, electric_ray 0.14, wreck 0.06, snorkel 0.05, 134.6ms
# Speed: 33.0ms preprocess, 134.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.18, electric_ray 0.09, stingray 0.08, shower_cap 0.07, tub 0.04, 34.0ms
# Speed: 12.7ms preprocess, 34.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.19, electric_ray 0.18, stingray 0.16, wreck 0.06, snorkel 0.04, 74.9ms
# Speed: 120.2ms preprocess, 74.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.16, dugong 0.14, electric_ray 0.13, wreck 0.07, snorkel 0.04, 30.3ms
# Speed: 8.1ms preprocess, 30.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.20, stingray 0.11, dugong 0.10, neck_brace 0.04, wreck 0.04, 33.7ms
# Speed: 10.3ms preprocess, 33.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.23, stingray 0.11, dugong 0.08, jellyfish 0.08, wreck 0.06, 29.1ms
# Speed: 10.7ms preprocess, 29.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.13, stingray 0.11, dugong 0.10, jellyfish 0.08, neck_brace 0.06, 34.0ms
# Speed: 10.5ms preprocess, 34.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.17, stingray 0.07, jellyfish 0.06, neck_brace 0.05, shower_cap 0.05, 32.2ms
# Speed: 9.1ms preprocess, 32.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.20, dugong 0.15, stingray 0.15, wreck 0.05, jellyfish 0.05, 25.4ms
# Speed: 9.9ms preprocess, 25.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, dugong 0.14, electric_ray 0.14, wreck 0.07, jellyfish 0.07, 39.7ms
# Speed: 9.1ms preprocess, 39.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.17, stingray 0.13, dugong 0.13, jellyfish 0.05, wreck 0.04, 65.2ms
# Speed: 12.3ms preprocess, 65.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.17, dugong 0.15, electric_ray 0.12, jellyfish 0.06, wreck 0.04, 34.5ms
# Speed: 9.4ms preprocess, 34.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.16, dugong 0.16, stingray 0.09, wreck 0.06, neck_brace 0.04, 25.9ms
# Speed: 7.7ms preprocess, 25.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.19, electric_ray 0.13, stingray 0.11, wreck 0.06, neck_brace 0.06, 27.3ms
# Speed: 10.6ms preprocess, 27.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.11, dugong 0.11, stingray 0.07, neck_brace 0.07, snorkel 0.06, 30.1ms
# Speed: 8.8ms preprocess, 30.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.17, stingray 0.11, dugong 0.09, neck_brace 0.06, jellyfish 0.05, 28.4ms
# Speed: 10.2ms preprocess, 28.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.19, stingray 0.14, dugong 0.06, wreck 0.06, neck_brace 0.05, 22.9ms
# Speed: 11.0ms preprocess, 22.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.32, stingray 0.17, dugong 0.09, wreck 0.07, snorkel 0.04, 28.2ms
# Speed: 11.5ms preprocess, 28.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.29, stingray 0.12, dugong 0.07, wreck 0.05, neck_brace 0.05, 22.7ms
# Speed: 9.6ms preprocess, 22.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.16, electric_ray 0.15, dugong 0.07, wreck 0.06, snorkel 0.06, 23.2ms
# Speed: 8.4ms preprocess, 23.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.13, electric_ray 0.13, wreck 0.09, dugong 0.07, neck_brace 0.05, 31.4ms
# Speed: 8.7ms preprocess, 31.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.21, electric_ray 0.18, dugong 0.09, jellyfish 0.07, snorkel 0.07, 21.2ms
# Speed: 10.5ms preprocess, 21.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.12, stingray 0.09, dugong 0.07, wreck 0.06, shower_cap 0.05, 26.1ms
# Speed: 14.2ms preprocess, 26.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.26, stingray 0.18, wreck 0.06, dugong 0.05, jellyfish 0.04, 19.5ms
# Speed: 9.9ms preprocess, 19.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.25, stingray 0.15, dugong 0.07, wreck 0.07, neck_brace 0.05, 34.1ms
# Speed: 15.1ms preprocess, 34.1ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.16, stingray 0.13, dugong 0.09, wreck 0.07, neck_brace 0.07, 36.8ms
# Speed: 9.2ms preprocess, 36.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.11, electric_ray 0.11, stingray 0.09, neck_brace 0.07, jellyfish 0.06, 33.0ms
# Speed: 9.1ms preprocess, 33.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dugong 0.16, electric_ray 0.11, stingray 0.08, wreck 0.07, snorkel 0.06, 36.0ms
# Speed: 9.8ms preprocess, 36.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.13, electric_ray 0.13, dugong 0.05, wreck 0.05, jellyfish 0.05, 50.7ms
# Speed: 8.8ms preprocess, 50.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, electric_ray 0.13, neck_brace 0.08, snorkel 0.07, jellyfish 0.05, 41.2ms
# Speed: 8.8ms preprocess, 41.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.12, stingray 0.10, neck_brace 0.10, dugong 0.06, wreck 0.05, 25.1ms
# Speed: 10.4ms preprocess, 25.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.20, stingray 0.13, dugong 0.09, neck_brace 0.05, jellyfish 0.04, 42.2ms
# Speed: 10.9ms preprocess, 42.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.13, dugong 0.09, stingray 0.08, neck_brace 0.07, jellyfish 0.07, 33.2ms
# Speed: 11.2ms preprocess, 33.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.12, electric_ray 0.09, snorkel 0.08, dugong 0.08, wreck 0.07, 31.8ms
# Speed: 13.9ms preprocess, 31.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.19, stingray 0.13, dugong 0.09, jellyfish 0.07, neck_brace 0.04, 29.3ms
# Speed: 10.1ms preprocess, 29.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 wig 0.10, shower_cap 0.07, electric_ray 0.07, stingray 0.07, neck_brace 0.06, 34.4ms
# Speed: 14.4ms preprocess, 34.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.11, dugong 0.10, stingray 0.09, wreck 0.06, jellyfish 0.05, 33.5ms
# Speed: 8.6ms preprocess, 33.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.12, stingray 0.10, shower_cap 0.06, dugong 0.06, neck_brace 0.05, 23.9ms
# Speed: 22.6ms preprocess, 23.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.09, shower_cap 0.08, jellyfish 0.07, stingray 0.07, wig 0.07, 39.5ms
# Speed: 14.0ms preprocess, 39.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.11, stingray 0.10, neck_brace 0.09, jellyfish 0.08, shower_cap 0.08, 34.0ms
# Speed: 10.2ms preprocess, 34.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.09, electric_ray 0.08, stingray 0.06, shower_cap 0.06, dugong 0.05, 29.9ms
# Speed: 8.7ms preprocess, 29.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.13, electric_ray 0.11, dugong 0.10, neck_brace 0.09, wreck 0.07, 28.3ms
# Speed: 10.4ms preprocess, 28.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.10, neck_brace 0.09, electric_ray 0.08, jellyfish 0.08, shower_cap 0.06, 38.2ms
# Speed: 11.1ms preprocess, 38.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.10, dugong 0.10, electric_ray 0.08, neck_brace 0.06, wreck 0.05, 30.1ms
# Speed: 7.7ms preprocess, 30.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.14, stingray 0.12, jellyfish 0.10, shower_cap 0.07, dugong 0.05, 34.5ms
# Speed: 10.0ms preprocess, 34.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.15, stingray 0.10, dugong 0.08, shower_cap 0.07, neck_brace 0.06, 58.0ms
# Speed: 12.4ms preprocess, 58.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.14, stingray 0.13, jellyfish 0.08, shower_cap 0.05, neck_brace 0.04, 37.7ms
# Speed: 107.2ms preprocess, 37.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.23, stingray 0.17, jellyfish 0.10, dugong 0.08, neck_brace 0.03, 354.8ms
# Speed: 59.1ms preprocess, 354.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 shower_cap 0.11, neck_brace 0.08, electric_ray 0.07, wig 0.07, stingray 0.06, 151.1ms
# Speed: 8.9ms preprocess, 151.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.14, stingray 0.11, dugong 0.06, neck_brace 0.06, shower_cap 0.05, 61.0ms
# Speed: 9.3ms preprocess, 61.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.11, electric_ray 0.10, jellyfish 0.10, shower_cap 0.06, dugong 0.06, 31.0ms
# Speed: 9.3ms preprocess, 31.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.09, electric_ray 0.08, neck_brace 0.08, jellyfish 0.07, dugong 0.06, 32.8ms
# Speed: 9.4ms preprocess, 32.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.12, electric_ray 0.09, jellyfish 0.09, neck_brace 0.08, wig 0.06, 35.1ms
# Speed: 10.1ms preprocess, 35.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.14, electric_ray 0.14, jellyfish 0.08, dugong 0.06, neck_brace 0.05, 171.8ms
# Speed: 59.6ms preprocess, 171.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.08, stingray 0.08, neck_brace 0.07, wig 0.07, shower_cap 0.06, 135.6ms
# Speed: 143.1ms preprocess, 135.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.13, electric_ray 0.08, jellyfish 0.07, shower_cap 0.07, dugong 0.06, 133.2ms
# Speed: 167.5ms preprocess, 133.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.14, stingray 0.12, jellyfish 0.08, dugong 0.07, neck_brace 0.06, 28.3ms
# Speed: 10.0ms preprocess, 28.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.19, stingray 0.10, shower_cap 0.06, jellyfish 0.05, wreck 0.05, 41.7ms
# Speed: 9.9ms preprocess, 41.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.18, wig 0.09, stingray 0.05, dugong 0.04, tub 0.03, 22.2ms
# Speed: 11.6ms preprocess, 22.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.27, neck_brace 0.08, jellyfish 0.08, stingray 0.03, wig 0.03, 45.4ms
# Speed: 8.3ms preprocess, 45.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.24, stingray 0.16, neck_brace 0.08, jellyfish 0.05, dugong 0.03, 101.7ms
# Speed: 10.9ms preprocess, 101.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.19, neck_brace 0.15, stingray 0.11, jellyfish 0.05, dugong 0.03, 77.8ms
# Speed: 21.8ms preprocess, 77.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.21, neck_brace 0.11, dugong 0.08, stingray 0.05, jellyfish 0.04, 114.7ms
# Speed: 12.5ms preprocess, 114.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.33, neck_brace 0.09, dugong 0.06, jellyfish 0.05, stingray 0.04, 137.9ms
# Speed: 58.3ms preprocess, 137.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.17, jellyfish 0.15, neck_brace 0.07, shower_cap 0.07, stingray 0.05, 23.5ms
# Speed: 9.7ms preprocess, 23.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.19, electric_ray 0.14, jellyfish 0.09, neck_brace 0.08, shower_cap 0.06, 37.3ms
# Speed: 11.2ms preprocess, 37.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.17, electric_ray 0.16, neck_brace 0.11, puck 0.06, shower_cap 0.05, 33.6ms
# Speed: 9.5ms preprocess, 33.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.14, neck_brace 0.12, electric_ray 0.11, jellyfish 0.05, shower_cap 0.04, 34.6ms
# Speed: 9.0ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.21, electric_ray 0.15, neck_brace 0.07, shower_cap 0.06, jellyfish 0.04, 28.7ms
# Speed: 11.1ms preprocess, 28.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.20, stingray 0.20, neck_brace 0.07, jellyfish 0.04, dugong 0.03, 29.2ms
# Speed: 9.4ms preprocess, 29.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.26, neck_brace 0.11, electric_ray 0.09, snorkel 0.06, wreck 0.05, 28.4ms
# Speed: 10.8ms preprocess, 28.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.25, electric_ray 0.11, snorkel 0.06, neck_brace 0.05, wreck 0.04, 30.4ms
# Speed: 10.9ms preprocess, 30.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.19, stingray 0.18, neck_brace 0.08, jellyfish 0.06, oxygen_mask 0.04, 41.5ms
# Speed: 11.4ms preprocess, 41.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.32, electric_ray 0.19, wreck 0.10, dugong 0.05, neck_brace 0.04, 33.4ms
# Speed: 8.3ms preprocess, 33.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.28, snorkel 0.15, electric_ray 0.08, wreck 0.06, neck_brace 0.05, 39.4ms
# Speed: 11.2ms preprocess, 39.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.22, electric_ray 0.11, wreck 0.09, snorkel 0.04, neck_brace 0.04, 25.0ms
# Speed: 23.4ms preprocess, 25.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.24, snorkel 0.09, electric_ray 0.08, wreck 0.07, neck_brace 0.05, 31.7ms
# Speed: 9.3ms preprocess, 31.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.45, electric_ray 0.11, wreck 0.06, snorkel 0.05, dugong 0.02, 39.3ms
# Speed: 9.0ms preprocess, 39.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.50, electric_ray 0.09, wreck 0.06, snorkel 0.02, hammerhead 0.02, 31.2ms
# Speed: 11.4ms preprocess, 31.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.47, electric_ray 0.12, snorkel 0.07, dugong 0.02, hammerhead 0.02, 31.1ms
# Speed: 9.8ms preprocess, 31.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.41, snorkel 0.08, electric_ray 0.07, cleaver 0.03, neck_brace 0.03, 53.4ms
# Speed: 9.2ms preprocess, 53.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.27, electric_ray 0.06, cleaver 0.04, whistle 0.04, snorkel 0.04, 35.9ms
# Speed: 9.9ms preprocess, 35.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.29, electric_ray 0.12, cleaver 0.07, ice_lolly 0.04, wreck 0.04, 32.4ms
# Speed: 11.0ms preprocess, 32.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.47, electric_ray 0.09, cleaver 0.03, snorkel 0.03, hammerhead 0.03, 31.5ms
# Speed: 14.2ms preprocess, 31.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.42, electric_ray 0.10, neck_brace 0.04, shovel 0.03, snorkel 0.02, 81.6ms
# Speed: 10.0ms preprocess, 81.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.41, electric_ray 0.09, snorkel 0.04, cleaver 0.03, wreck 0.03, 26.8ms
# Speed: 13.2ms preprocess, 26.8ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.32, electric_ray 0.09, snorkel 0.04, wreck 0.03, cleaver 0.03, 27.4ms
# Speed: 10.9ms preprocess, 27.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.29, electric_ray 0.08, cleaver 0.05, envelope 0.03, snorkel 0.02, 29.6ms
# Speed: 11.9ms preprocess, 29.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.38, electric_ray 0.17, snorkel 0.06, hammerhead 0.04, dugong 0.03, 28.3ms
# Speed: 10.5ms preprocess, 28.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.43, electric_ray 0.07, cleaver 0.05, dugong 0.03, wreck 0.03, 24.1ms
# Speed: 9.1ms preprocess, 24.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.40, electric_ray 0.09, snorkel 0.06, dugong 0.04, neck_brace 0.04, 31.7ms
# Speed: 11.9ms preprocess, 31.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.28, electric_ray 0.16, neck_brace 0.08, snorkel 0.06, hammerhead 0.03, 59.3ms
# Speed: 112.4ms preprocess, 59.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.34, electric_ray 0.09, wreck 0.06, snorkel 0.03, whistle 0.03, 23.4ms
# Speed: 8.5ms preprocess, 23.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.13, snorkel 0.08, dumbbell 0.05, jellyfish 0.03, envelope 0.03, 31.5ms
# Speed: 9.6ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.38, electric_ray 0.08, neck_brace 0.05, tub 0.04, jellyfish 0.03, 31.9ms
# Speed: 9.8ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.28, electric_ray 0.07, neck_brace 0.06, envelope 0.04, jellyfish 0.03, 27.1ms
# Speed: 10.7ms preprocess, 27.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.23, jigsaw_puzzle 0.06, snorkel 0.06, envelope 0.05, dumbbell 0.04, 29.5ms
# Speed: 10.0ms preprocess, 29.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 laptop 0.16, stingray 0.15, switch 0.08, envelope 0.05, lighter 0.05, 32.8ms
# Speed: 13.1ms preprocess, 32.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 laptop 0.19, stingray 0.10, snorkel 0.08, lighter 0.07, switch 0.05, 34.0ms
# Speed: 9.4ms preprocess, 34.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 laptop 0.10, envelope 0.10, switch 0.10, lighter 0.06, syringe 0.05, 26.3ms
# Speed: 11.9ms preprocess, 26.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.38, oxygen_mask 0.12, snorkel 0.07, electric_ray 0.06, envelope 0.02, 39.3ms
# Speed: 11.1ms preprocess, 39.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.18, envelope 0.07, oxygen_mask 0.05, electric_ray 0.04, snorkel 0.03, 33.6ms
# Speed: 8.9ms preprocess, 33.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.39, envelope 0.12, oxygen_mask 0.05, switch 0.03, electric_ray 0.03, 33.2ms
# Speed: 10.7ms preprocess, 33.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.19, envelope 0.15, laptop 0.06, switch 0.05, oxygen_mask 0.03, 33.1ms
# Speed: 15.2ms preprocess, 33.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.14, stingray 0.13, syringe 0.06, snorkel 0.04, wallet 0.04, 26.2ms
# Speed: 10.2ms preprocess, 26.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.26, stingray 0.09, switch 0.05, laptop 0.05, oxygen_mask 0.05, 29.6ms
# Speed: 9.6ms preprocess, 29.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.19, envelope 0.12, syringe 0.05, snorkel 0.05, oxygen_mask 0.05, 32.6ms
# Speed: 10.8ms preprocess, 32.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, envelope 0.08, switch 0.05, jigsaw_puzzle 0.03, syringe 0.03, 31.1ms
# Speed: 9.9ms preprocess, 31.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.23, stingray 0.10, book_jacket 0.06, switch 0.05, wallet 0.04, 35.1ms
# Speed: 10.4ms preprocess, 35.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.19, stingray 0.10, switch 0.07, wallet 0.04, book_jacket 0.04, 35.9ms
# Speed: 8.3ms preprocess, 35.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.29, envelope 0.07, ice_lolly 0.06, switch 0.04, laptop 0.03, 32.9ms
# Speed: 9.7ms preprocess, 32.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.16, envelope 0.15, electric_ray 0.04, book_jacket 0.04, switch 0.03, 47.5ms
# Speed: 118.7ms preprocess, 47.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.16, stingray 0.12, book_jacket 0.05, jigsaw_puzzle 0.05, wallet 0.05, 24.4ms
# Speed: 11.8ms preprocess, 24.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.09, stingray 0.09, jigsaw_puzzle 0.05, switch 0.05, book_jacket 0.03, 36.5ms
# Speed: 10.1ms preprocess, 36.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.26, envelope 0.06, lighter 0.05, wallet 0.04, laptop 0.04, 31.9ms
# Speed: 11.2ms preprocess, 31.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.13, laptop 0.10, book_jacket 0.08, stingray 0.06, switch 0.06, 31.3ms
# Speed: 11.3ms preprocess, 31.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 wallet 0.12, envelope 0.09, switch 0.07, laptop 0.06, book_jacket 0.05, 30.3ms
# Speed: 9.8ms preprocess, 30.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, laptop 0.07, switch 0.07, book_jacket 0.06, envelope 0.05, 32.4ms
# Speed: 9.8ms preprocess, 32.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 laptop 0.12, book_jacket 0.10, envelope 0.10, stingray 0.08, switch 0.04, 31.2ms
# Speed: 8.5ms preprocess, 31.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.11, envelope 0.10, laptop 0.08, switch 0.07, book_jacket 0.07, 29.8ms
# Speed: 9.4ms preprocess, 29.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.09, envelope 0.09, book_jacket 0.08, wallet 0.07, laptop 0.06, 41.6ms
# Speed: 10.7ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, laptop 0.11, wallet 0.08, envelope 0.08, switch 0.06, 34.4ms
# Speed: 9.4ms preprocess, 34.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.14, stingray 0.14, laptop 0.05, oxygen_mask 0.05, syringe 0.04, 31.5ms
# Speed: 9.9ms preprocess, 31.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, envelope 0.06, oxygen_mask 0.05, syringe 0.05, switch 0.04, 27.2ms
# Speed: 9.3ms preprocess, 27.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.20, snorkel 0.06, switch 0.05, neck_brace 0.04, jigsaw_puzzle 0.04, 24.9ms
# Speed: 7.8ms preprocess, 24.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.25, electric_ray 0.07, envelope 0.06, book_jacket 0.04, neck_brace 0.04, 47.7ms
# Speed: 16.6ms preprocess, 47.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.13, switch 0.05, envelope 0.04, oxygen_mask 0.04, neck_brace 0.04, 49.6ms
# Speed: 8.7ms preprocess, 49.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, envelope 0.06, switch 0.04, electric_ray 0.03, jellyfish 0.03, 33.4ms
# Speed: 9.2ms preprocess, 33.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.18, envelope 0.07, snorkel 0.06, switch 0.04, neck_brace 0.04, 31.7ms
# Speed: 9.1ms preprocess, 31.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.16, snorkel 0.10, jellyfish 0.08, neck_brace 0.05, oxygen_mask 0.04, 22.9ms
# Speed: 10.7ms preprocess, 22.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.38, snorkel 0.19, oxygen_mask 0.14, electric_ray 0.06, hammerhead 0.03, 217.5ms
# Speed: 10.2ms preprocess, 217.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 snorkel 0.23, oxygen_mask 0.12, dumbbell 0.12, stingray 0.11, electric_ray 0.07, 32.8ms
# Speed: 8.1ms preprocess, 32.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 snorkel 0.24, electric_ray 0.17, oxygen_mask 0.14, stingray 0.12, platypus 0.05, 29.6ms
# Speed: 8.9ms preprocess, 29.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 tarantula 0.11, platypus 0.09, spider_monkey 0.07, oxygen_mask 0.06, stingray 0.06, 34.1ms
# Speed: 11.6ms preprocess, 34.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 hammerhead 0.09, spider_monkey 0.06, axolotl 0.05, tarantula 0.04, platypus 0.04, 27.7ms
# Speed: 11.5ms preprocess, 27.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 hammerhead 0.20, syringe 0.09, snorkel 0.06, Band_Aid 0.06, jellyfish 0.05, 24.7ms
# Speed: 8.9ms preprocess, 24.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 ping-pong_ball 0.13, hair_spray 0.11, hand_blower 0.07, matchstick 0.05, jellyfish 0.04, 41.2ms
# Speed: 8.1ms preprocess, 41.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 hammerhead 0.17, stingray 0.07, hand_blower 0.07, neck_brace 0.06, syringe 0.06, 30.6ms
# Speed: 9.4ms preprocess, 30.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 jellyfish 0.17, dumbbell 0.10, snorkel 0.07, dugong 0.06, hand_blower 0.06, 83.4ms
# Speed: 12.2ms preprocess, 83.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 great_white_shark 0.10, axolotl 0.07, sunscreen 0.06, stingray 0.04, hammerhead 0.04, 44.0ms
# Speed: 9.9ms preprocess, 44.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 great_white_shark 0.36, tiger_shark 0.21, hammerhead 0.08, snorkel 0.05, stingray 0.04, 23.1ms
# Speed: 8.8ms preprocess, 23.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.17, dumbbell 0.04, sea_lion 0.04, lighter 0.04, great_white_shark 0.04, 28.1ms
# Speed: 11.8ms preprocess, 28.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.26, neck_brace 0.09, laptop 0.07, jigsaw_puzzle 0.04, book_jacket 0.02, 34.3ms
# Speed: 11.7ms preprocess, 34.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 sea_lion 0.21, stingray 0.11, dugong 0.08, hammerhead 0.08, dumbbell 0.03, 25.4ms
# Speed: 9.9ms preprocess, 25.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 sea_lion 0.18, stingray 0.13, dumbbell 0.10, hammerhead 0.09, mortar 0.08, 36.9ms
# Speed: 8.5ms preprocess, 36.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 jellyfish 0.23, stingray 0.16, electric_ray 0.07, envelope 0.05, snorkel 0.04, 37.7ms
# Speed: 8.5ms preprocess, 37.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 jellyfish 0.30, stingray 0.17, snorkel 0.06, electric_ray 0.06, tub 0.03, 36.6ms
# Speed: 9.6ms preprocess, 36.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.32, jellyfish 0.13, snorkel 0.10, electric_ray 0.08, neck_brace 0.05, 33.8ms
# Speed: 8.8ms preprocess, 33.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.21, snorkel 0.19, jellyfish 0.07, neck_brace 0.07, tub 0.04, 60.7ms
# Speed: 9.8ms preprocess, 60.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 snorkel 0.22, stingray 0.18, neck_brace 0.13, electric_ray 0.08, wreck 0.03, 28.8ms
# Speed: 9.8ms preprocess, 28.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.37, snorkel 0.10, stingray 0.09, electric_ray 0.06, oxygen_mask 0.05, 150.1ms
# Speed: 16.8ms preprocess, 150.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.23, oxygen_mask 0.09, stingray 0.08, whistle 0.05, snorkel 0.04, 31.1ms
# Speed: 8.4ms preprocess, 31.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.31, snorkel 0.07, oxygen_mask 0.05, dumbbell 0.05, switch 0.04, 28.4ms
# Speed: 13.3ms preprocess, 28.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.19, snorkel 0.14, neck_brace 0.07, jellyfish 0.05, electric_ray 0.04, 32.1ms
# Speed: 12.5ms preprocess, 32.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.26, snorkel 0.12, neck_brace 0.08, oxygen_mask 0.06, hammerhead 0.03, 31.2ms
# Speed: 9.1ms preprocess, 31.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.12, dumbbell 0.10, cellular_telephone 0.08, laptop 0.05, stingray 0.05, 26.8ms
# Speed: 20.6ms preprocess, 26.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.16, cellular_telephone 0.14, laptop 0.11, iPod 0.06, lighter 0.06, 29.8ms
# Speed: 11.8ms preprocess, 29.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.17, cellular_telephone 0.14, laptop 0.06, lighter 0.05, whistle 0.04, 31.5ms
# Speed: 9.7ms preprocess, 31.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 oxygen_mask 0.09, switch 0.08, snorkel 0.05, lighter 0.05, whistle 0.05, 33.1ms
# Speed: 13.0ms preprocess, 33.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 laptop 0.07, dumbbell 0.06, snorkel 0.06, stingray 0.06, lighter 0.05, 32.1ms
# Speed: 10.3ms preprocess, 32.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 lighter 0.12, switch 0.09, stingray 0.08, ice_lolly 0.06, dumbbell 0.06, 31.1ms
# Speed: 9.3ms preprocess, 31.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 lighter 0.25, switch 0.13, cellular_telephone 0.07, laptop 0.04, whistle 0.04, 34.7ms
# Speed: 20.7ms preprocess, 34.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 lighter 0.16, switch 0.16, whistle 0.07, ice_lolly 0.06, dumbbell 0.05, 32.9ms
# Speed: 18.6ms preprocess, 32.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 ice_lolly 0.10, lighter 0.09, whistle 0.07, switch 0.05, stingray 0.05, 29.1ms
# Speed: 8.7ms preprocess, 29.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 lighter 0.11, ice_lolly 0.08, stingray 0.08, switch 0.08, dumbbell 0.05, 30.6ms
# Speed: 11.8ms preprocess, 30.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 ice_lolly 0.14, switch 0.12, stingray 0.09, lighter 0.08, dumbbell 0.06, 32.0ms
# Speed: 10.4ms preprocess, 32.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 ice_lolly 0.10, switch 0.10, dumbbell 0.10, lighter 0.06, stingray 0.04, 39.2ms
# Speed: 10.3ms preprocess, 39.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 ice_lolly 0.24, switch 0.08, lighter 0.08, envelope 0.05, whistle 0.04, 31.4ms
# Speed: 9.4ms preprocess, 31.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.17, ice_lolly 0.10, switch 0.10, lighter 0.09, laptop 0.05, 120.8ms
# Speed: 23.9ms preprocess, 120.8ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.10, stingray 0.09, switch 0.07, laptop 0.06, oxygen_mask 0.04, 36.0ms
# Speed: 9.3ms preprocess, 36.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 envelope 0.19, switch 0.08, stingray 0.08, laptop 0.07, book_jacket 0.04, 28.2ms
# Speed: 8.0ms preprocess, 28.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.13, envelope 0.12, ice_lolly 0.09, lighter 0.07, whistle 0.05, 31.4ms
# Speed: 9.3ms preprocess, 31.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 lighter 0.15, switch 0.15, laptop 0.06, envelope 0.05, ice_lolly 0.04, 29.9ms
# Speed: 10.0ms preprocess, 29.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 laptop 0.14, switch 0.13, lighter 0.11, envelope 0.07, whistle 0.04, 39.8ms
# Speed: 11.3ms preprocess, 39.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 lighter 0.20, switch 0.18, ice_lolly 0.06, laptop 0.06, stingray 0.05, 33.9ms
# Speed: 8.8ms preprocess, 33.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 lighter 0.24, switch 0.19, whistle 0.08, dumbbell 0.06, laptop 0.04, 27.2ms
# Speed: 10.2ms preprocess, 27.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.20, lighter 0.14, dumbbell 0.10, whistle 0.04, laptop 0.03, 28.0ms
# Speed: 9.8ms preprocess, 28.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.22, lighter 0.14, dumbbell 0.06, stingray 0.04, sunscreen 0.03, 25.6ms
# Speed: 12.5ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.13, stingray 0.11, lighter 0.08, dumbbell 0.04, envelope 0.04, 34.1ms
# Speed: 8.4ms preprocess, 34.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.19, lighter 0.09, envelope 0.05, whistle 0.05, syringe 0.05, 31.3ms
# Speed: 11.5ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.25, lighter 0.14, laptop 0.08, stingray 0.04, sunscreen 0.03, 54.3ms
# Speed: 13.9ms preprocess, 54.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.24, lighter 0.13, whistle 0.05, envelope 0.05, laptop 0.03, 76.6ms
# Speed: 7.4ms preprocess, 76.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.21, lighter 0.08, stingray 0.07, cellular_telephone 0.04, envelope 0.03, 25.7ms
# Speed: 9.2ms preprocess, 25.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.23, lighter 0.08, envelope 0.08, laptop 0.04, ice_lolly 0.03, 46.9ms
# Speed: 10.2ms preprocess, 46.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.21, lighter 0.07, envelope 0.06, stingray 0.04, laptop 0.04, 27.2ms
# Speed: 10.0ms preprocess, 27.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.22, lighter 0.07, stingray 0.07, whistle 0.04, syringe 0.04, 28.0ms
# Speed: 15.8ms preprocess, 28.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.15, stingray 0.12, lighter 0.09, whistle 0.04, dumbbell 0.03, 33.0ms
# Speed: 10.5ms preprocess, 33.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.38, lighter 0.14, stingray 0.05, laptop 0.03, whistle 0.03, 29.5ms
# Speed: 10.3ms preprocess, 29.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.35, lighter 0.10, stingray 0.06, laptop 0.03, whistle 0.03, 54.6ms
# Speed: 95.8ms preprocess, 54.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.20, lighter 0.16, syringe 0.06, stingray 0.04, whistle 0.04, 33.8ms
# Speed: 7.9ms preprocess, 33.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.24, lighter 0.11, stingray 0.06, envelope 0.04, sunscreen 0.04, 33.4ms
# Speed: 15.4ms preprocess, 33.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.26, lighter 0.10, stingray 0.06, syringe 0.05, whistle 0.04, 26.1ms
# Speed: 12.1ms preprocess, 26.1ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.11, switch 0.07, sunscreen 0.05, jigsaw_puzzle 0.04, envelope 0.04, 27.6ms
# Speed: 8.8ms preprocess, 27.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, syringe 0.05, neck_brace 0.04, switch 0.04, sunscreen 0.04, 37.1ms
# Speed: 13.1ms preprocess, 37.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.12, dumbbell 0.11, joystick 0.07, stingray 0.06, lighter 0.05, 27.4ms
# Speed: 10.8ms preprocess, 27.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.22, syringe 0.05, neck_brace 0.04, oxygen_mask 0.03, switch 0.03, 39.1ms
# Speed: 13.4ms preprocess, 39.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.14, switch 0.06, neck_brace 0.05, envelope 0.04, dumbbell 0.04, 31.8ms
# Speed: 8.8ms preprocess, 31.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.11, dumbbell 0.06, envelope 0.05, neck_brace 0.05, joystick 0.04, 28.2ms
# Speed: 14.4ms preprocess, 28.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, dumbbell 0.06, switch 0.05, syringe 0.04, envelope 0.03, 42.6ms
# Speed: 9.1ms preprocess, 42.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.19, neck_brace 0.05, syringe 0.04, oxygen_mask 0.04, envelope 0.03, 104.3ms
# Speed: 9.6ms preprocess, 104.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.23, switch 0.05, neck_brace 0.05, dumbbell 0.04, envelope 0.04, 28.2ms
# Speed: 8.6ms preprocess, 28.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.21, switch 0.06, envelope 0.05, syringe 0.03, neck_brace 0.03, 26.0ms
# Speed: 9.2ms preprocess, 26.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.36, envelope 0.03, switch 0.03, ice_lolly 0.03, syringe 0.03, 34.9ms
# Speed: 8.5ms preprocess, 34.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dumbbell 0.10, stingray 0.07, switch 0.04, neck_brace 0.04, joystick 0.04, 35.6ms
# Speed: 7.9ms preprocess, 35.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.08, stingray 0.08, jigsaw_puzzle 0.04, joystick 0.04, syringe 0.04, 26.2ms
# Speed: 9.3ms preprocess, 26.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.08, neck_brace 0.06, jigsaw_puzzle 0.05, dumbbell 0.04, stingray 0.04, 33.1ms
# Speed: 11.8ms preprocess, 33.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.14, syringe 0.07, stingray 0.07, joystick 0.05, envelope 0.05, 40.0ms
# Speed: 51.6ms preprocess, 40.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.15, syringe 0.06, envelope 0.05, whistle 0.04, stingray 0.04, 35.7ms
# Speed: 9.0ms preprocess, 35.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.18, neck_brace 0.07, dumbbell 0.06, jigsaw_puzzle 0.04, puck 0.03, 28.3ms
# Speed: 25.4ms preprocess, 28.3ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.09, stingray 0.08, syringe 0.07, jigsaw_puzzle 0.04, envelope 0.04, 32.6ms
# Speed: 25.8ms preprocess, 32.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.18, neck_brace 0.10, jigsaw_puzzle 0.05, switch 0.04, envelope 0.03, 25.5ms
# Speed: 11.3ms preprocess, 25.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.09, switch 0.07, stingray 0.06, envelope 0.05, oxygen_mask 0.04, 28.1ms
# Speed: 9.4ms preprocess, 28.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.12, stingray 0.11, neck_brace 0.06, jigsaw_puzzle 0.04, envelope 0.04, 28.4ms
# Speed: 8.7ms preprocess, 28.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, jigsaw_puzzle 0.07, neck_brace 0.05, envelope 0.05, switch 0.05, 26.4ms
# Speed: 10.7ms preprocess, 26.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.10, switch 0.10, neck_brace 0.07, envelope 0.05, jigsaw_puzzle 0.04, 28.1ms
# Speed: 8.0ms preprocess, 28.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.12, switch 0.07, envelope 0.04, neck_brace 0.04, jigsaw_puzzle 0.04, 26.9ms
# Speed: 9.4ms preprocess, 26.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.17, stingray 0.07, jigsaw_puzzle 0.05, envelope 0.04, dumbbell 0.04, 39.9ms
# Speed: 19.0ms preprocess, 39.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.08, switch 0.08, envelope 0.05, neck_brace 0.05, jigsaw_puzzle 0.04, 93.0ms
# Speed: 9.9ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.09, switch 0.08, jigsaw_puzzle 0.06, envelope 0.05, stingray 0.05, 35.0ms
# Speed: 8.3ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 neck_brace 0.11, stingray 0.10, switch 0.08, jigsaw_puzzle 0.05, dumbbell 0.03, 32.1ms
# Speed: 8.8ms preprocess, 32.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 switch 0.12, dumbbell 0.09, envelope 0.05, jigsaw_puzzle 0.05, whistle 0.04, 32.7ms
# Speed: 14.0ms preprocess, 32.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 dumbbell 0.10, switch 0.08, envelope 0.06, stingray 0.05, jigsaw_puzzle 0.04, 41.6ms
# Speed: 8.3ms preprocess, 41.6ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.16, jellyfish 0.13, neck_brace 0.11, electric_ray 0.07, shower_cap 0.04, 29.9ms
# Speed: 9.6ms preprocess, 29.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.18, electric_ray 0.10, neck_brace 0.09, jellyfish 0.09, snorkel 0.05, 38.7ms
# Speed: 9.0ms preprocess, 38.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.13, tub 0.10, shower_cap 0.07, stingray 0.07, dugong 0.06, 32.0ms
# Speed: 9.6ms preprocess, 32.0ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.22, stingray 0.10, dugong 0.09, oxygen_mask 0.06, snorkel 0.05, 144.1ms
# Speed: 10.6ms preprocess, 144.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.24, stingray 0.18, jellyfish 0.07, dugong 0.07, neck_brace 0.04, 43.8ms
# Speed: 8.6ms preprocess, 43.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.16, stingray 0.09, oxygen_mask 0.08, dugong 0.07, neck_brace 0.05, 28.1ms
# Speed: 11.7ms preprocess, 28.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.14, electric_ray 0.14, oxygen_mask 0.13, neck_brace 0.05, shower_cap 0.05, 31.5ms
# Speed: 11.8ms preprocess, 31.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 electric_ray 0.20, neck_brace 0.08, stingray 0.08, jellyfish 0.07, oxygen_mask 0.07, 24.3ms
# Speed: 10.9ms preprocess, 24.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.15, electric_ray 0.11, neck_brace 0.06, tub 0.06, jellyfish 0.05, 29.4ms
# Speed: 10.1ms preprocess, 29.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.16, electric_ray 0.16, oxygen_mask 0.09, neck_brace 0.06, shower_cap 0.03, 31.8ms
# Speed: 9.2ms preprocess, 31.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.17, electric_ray 0.09, oxygen_mask 0.09, neck_brace 0.06, jellyfish 0.06, 29.7ms
# Speed: 17.5ms preprocess, 29.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 stingray 0.18, electric_ray 0.16, neck_brace 0.07, oxygen_mask 0.06, jellyfish 0.05, 23.2ms
# Speed: 9.8ms preprocess, 23.2ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
