# %% [markdown]
# # With Image

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-pose.pt")

# Perform object detection on an image
results = model("../data/A7med.jpeg", conf=0.5)
results[0].show()
results[0].save()
# Out:
# image 1/1 /home/ahmedcr7/Programming/Python/AI/computer vision/yolov11/../data/A7med.jpeg: 640x640 1 person, 401.5ms
# Speed: 6.3ms preprocess, 401.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 'results_A7med.jpeg'

# %% [markdown]
# # With Video

# %%
import cv2
from ultralytics import YOLO

# Load the YOLO model
model = YOLO("yolo11n-pose.pt")

# Open the video file
# video_path = "../data/2.avi"
# cap = cv2.VideoCapture(video_path)

cap = cv2.VideoCapture(0)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-pose.pt to 'yolo11n-pose.pt'...
# 100%|██████████| 5.97M/5.97M [00:02<00:00, 2.23MB/s]
# 0: 480x640 1 person, 237.3ms
# Speed: 4.8ms preprocess, 237.3ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/ahmedcr7/.local/lib/python3.11/site-packages/cv2/qt/plugins"
# 0: 480x640 1 person, 404.5ms
# Speed: 5.0ms preprocess, 404.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 278.9ms
# Speed: 10.9ms preprocess, 278.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 481.0ms
# Speed: 3.2ms preprocess, 481.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.2ms
# Speed: 2.0ms preprocess, 181.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 235.3ms
# Speed: 2.7ms preprocess, 235.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.5ms
# Speed: 3.1ms preprocess, 183.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.0ms
# Speed: 3.7ms preprocess, 216.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.2ms
# Speed: 4.1ms preprocess, 206.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 193.0ms
# Speed: 5.0ms preprocess, 193.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.5ms
# Speed: 5.9ms preprocess, 178.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.0ms
# Speed: 2.6ms preprocess, 207.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.4ms
# Speed: 1.9ms preprocess, 165.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.2ms
# Speed: 4.6ms preprocess, 164.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 187.7ms
# Speed: 3.3ms preprocess, 187.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.4ms
# Speed: 3.7ms preprocess, 191.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.0ms
# Speed: 3.7ms preprocess, 170.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.3ms
# Speed: 3.1ms preprocess, 185.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.9ms
# Speed: 5.2ms preprocess, 194.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 191.2ms
# Speed: 3.8ms preprocess, 191.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 165.0ms
# Speed: 8.3ms preprocess, 165.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.6ms
# Speed: 3.3ms preprocess, 175.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 180.2ms
# Speed: 2.0ms preprocess, 180.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.0ms
# Speed: 2.1ms preprocess, 176.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 364.7ms
# Speed: 1.9ms preprocess, 364.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.6ms
# Speed: 5.2ms preprocess, 164.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.3ms
# Speed: 3.8ms preprocess, 181.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 182.1ms
# Speed: 2.4ms preprocess, 182.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.9ms
# Speed: 3.6ms preprocess, 181.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.4ms
# Speed: 3.0ms preprocess, 184.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 406.4ms
# Speed: 4.0ms preprocess, 406.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person,
3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 478.1ms
# Speed: 2.9ms preprocess, 478.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 383.3ms
# Speed: 2.0ms preprocess, 383.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.1ms
# Speed: 50.3ms preprocess, 207.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.2ms
# Speed: 6.4ms preprocess, 175.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.7ms
# Speed: 3.4ms preprocess, 173.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.5ms
# Speed: 34.0ms preprocess, 168.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 181.9ms
# Speed: 3.9ms preprocess, 181.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.5ms
# Speed: 5.3ms preprocess, 171.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 313.7ms
# Speed: 73.1ms preprocess, 313.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.5ms
# Speed: 4.2ms preprocess, 202.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 192.3ms
# Speed: 2.2ms preprocess, 192.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 151.6ms
# Speed: 2.2ms preprocess, 151.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 170.3ms
# Speed: 2.7ms preprocess, 170.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.6ms
# Speed: 19.0ms preprocess, 190.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 190.6ms
# Speed: 5.4ms preprocess, 190.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.1ms
# Speed: 3.4ms preprocess, 167.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 158.0ms
# Speed: 3.4ms preprocess, 158.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.5ms
# Speed: 2.3ms preprocess, 168.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.7ms
# Speed: 3.1ms preprocess, 184.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.2ms
# Speed: 3.8ms preprocess, 168.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.4ms
# Speed: 2.1ms preprocess, 184.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 186.6ms
# Speed: 4.9ms preprocess, 186.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.2ms
# Speed: 4.6ms preprocess, 184.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 188.1ms
# Speed: 2.0ms preprocess, 188.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.5ms
# Speed: 2.5ms preprocess, 184.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 158.8ms
# Speed: 15.4ms preprocess, 158.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.5ms
# Speed: 2.9ms preprocess, 179.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 251.4ms
# Speed: 43.6ms preprocess, 251.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 299.9ms
# Speed: 1.9ms preprocess, 299.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 320.2ms
# Speed: 9.8ms preprocess, 320.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 302.3ms
# Speed: 3.0ms preprocess, 302.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.5ms
# Speed: 4.0ms preprocess, 192.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.8ms
# Speed: 2.7ms preprocess, 171.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 184.0ms
# Speed: 3.5ms preprocess, 184.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.1ms
# Speed: 9.7ms preprocess, 178.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 181.1ms
# Speed: 6.9ms preprocess, 181.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.8ms
# Speed: 4.6ms preprocess, 171.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 287.1ms
# Speed: 2.9ms preprocess, 287.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.3ms
# Speed: 5.8ms preprocess, 173.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 173.5ms
# Speed: 4.1ms preprocess, 173.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.6ms
# Speed: 3.2ms preprocess, 189.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 178.5ms
# Speed: 4.4ms preprocess, 178.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.5ms
# Speed: 8.5ms preprocess, 162.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 176.8ms
# Speed: 6.2ms preprocess, 176.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 150.9ms
# Speed: 3.1ms preprocess, 150.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 231.4ms
# Speed: 2.4ms preprocess, 231.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 178.2ms
# Speed: 2.0ms preprocess, 178.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.3ms
# Speed: 2.1ms preprocess, 167.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.9ms
# Speed: 2.9ms preprocess, 171.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.5ms
# Speed: 3.9ms preprocess, 192.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.3ms
# Speed: 5.0ms preprocess, 202.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 215.8ms
# Speed: 3.5ms preprocess, 215.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
