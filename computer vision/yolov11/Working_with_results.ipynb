# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Run inference on an image
results = model("../data/bus.jpg")  # list of 1 Results object

for res in results:
    # print(res.boxes)  # Boxes object for bbox outputs
    # print(res.masks)  # Masks object for segmentation masks outputs
    # print(res.probs)  # Class probabilities for classification outputs
    # print(res.names) # Get class names
    # print(res.__getitem__(0)) # Get the first result
    # print(res.__len__()) # Get the number of results
    print(res.tojson())
# Out:
# image 1/1 /home/ahmedcr7/Programming/Python/AI/computer vision/yolov11/../data/bus.jpg: 640x480 4 persons, 1 bus, 358.4ms
# Speed: 13.2ms preprocess, 358.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# WARNING ⚠️ 'result.tojson()' is deprecated, replace with 'result.to_json()'.
# [
#   {
#     "name": "bus",
#     "class": 5,
#     "confidence": 0.93852,
#     "box": {
#       "x1": 8.13938,
#       "y1": 229.21269,
#       "x2": 794.70795,
#       "y2": 727.07574
#     }
#   },
#   {
#     "name": "person",
#     "class": 0,
#     "confidence": 0.89054,
#     "box": {
#       "x1": 670.39191,
#       "y1": 394.84122,
#       "x2": 809.8111,
#       "y2": 879.21283
#     }
#   },
#   {
#     "name": "person",
#     "class": 0,
#     "confidence": 0.87899,
#     "box": {
#       "x1": 47.24603,
#       "y1": 400.22824,
#       "x2": 239.33875,
#       "y2": 903.42273
#     }
#   },
#   {
#     "name": "person",
#     "class": 0,
#     "confidence": 0.85317,
#     "box": {
#       "x1": 223.40105,
#       "y1": 408.5668,
#       "x2": 344.40811,
#       "y2": 860.7735
#     }
#   },
#   {
#     "name": "person",
#     "class": 0,
#     "confidence": 0.68638,
#     "box": {
#       "x1": 0.0129,
#       "y1": 554.20087,
#       "x2": 68.5093,
#       "y2": 871.82263
#     }
#   }
# ]

# %%
import numpy as np
import cv2
from time import time
from ultralytics import YOLO


class ObjectDetection():
    def __init__(self, capture=0):
        self.capture_idx = capture
        self.model = self.load_model()
    
    def load_model(self):
        model = YOLO('yolo11n.pt')
        return model
    
    def predict(self, frame):
        result = self.model(frame)
        return result

    def plot_boxes(self, results, frame):
        confidence, class_idx = [],[]

        for res in results:
            boxes = res.boxes.numpy()

            confidence.append(boxes.conf)
            class_idx.append(boxes.cls)
            frame = results[0].plot()
        
        print(f"confidence -> {confidence}")
        print(f"class_idx -> {class_idx}")

        return frame
    
    def __call__(self):
        cap = cv2.VideoCapture(self.capture_idx)
        print(cap.isOpened())

        if cap.isOpened():
            cap.set(3, 1080)  # Width
            cap.set(4, 720)   # Height

            while True:
                start_time = time()

                ret, frame = cap.read()

                if not ret:
                    break

                results = self.predict(frame)
                frame = self.plot_boxes(results, frame)

                end_time = time()

                fps = 1/np.round(end_time - start_time, 2)

                cv2.putText(frame, f'FPS: {int(fps)}', (20,70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0,255,0), 2)
                cv2.imshow('frame', frame)

                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
    
        cap.release()
        cv2.destroyAllWindows()

detector = ObjectDetection(0)
detector()
# Out:
# True
#
# 0: 480x640 1 person, 147.2ms
# Speed: 2.9ms preprocess, 147.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.93325], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 212.8ms
# Speed: 41.4ms preprocess, 212.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92819], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 531.4ms
# Speed: 4.2ms preprocess, 531.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92888], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 366.3ms
# Speed: 11.3ms preprocess, 366.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.93194], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 248.8ms
# Speed: 18.0ms preprocess, 248.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.93008], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 459.3ms
# Speed: 6.1ms preprocess, 459.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.93498], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 182.1ms
# Speed: 10.7ms preprocess, 182.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.93592], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 169.4ms
# Speed: 3.6ms preprocess, 169.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92844], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 184.1ms
# Speed: 8.6ms preprocess, 184.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92933], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 173.7ms
# Speed: 7.0ms preprocess, 173.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92982], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 163.0ms
# Speed: 4.0ms preprocess, 163.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92879], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 183.0ms
# Speed: 12.8ms preprocess, 183.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92355], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 168.2ms
# Speed: 4.2ms preprocess, 168.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.91952], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 182.7ms
# Speed: 8.1ms preprocess, 182.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.90966], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 184.4ms
# Speed: 4.4ms preprocess, 184.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92297], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 178.1ms
# Speed: 4.4ms preprocess, 178.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92806], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 161.2ms
# Speed: 6.8ms preprocess, 161.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92136], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 179.1ms
# Speed: 25.3ms preprocess, 179.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.93175], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 165.9ms
# Speed: 8.6ms preprocess, 165.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.91848], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 168.4ms
# Speed: 4.6ms preprocess, 168.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92644], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 156.5ms
# Speed: 2.6ms preprocess, 156.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([     0.9301], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 202.9ms
# Speed: 4.9ms preprocess, 202.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.91006], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 161.6ms
# Speed: 4.7ms preprocess, 161.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92523], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 168.2ms
# Speed: 13.6ms preprocess, 168.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.90371], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]
#
# 0: 480x640 1 person, 177.8ms
# Speed: 8.2ms preprocess, 177.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# confidence -> [array([    0.92478], dtype=float32)]
# class_idx -> [array([          0], dtype=float32)]

# %%
from ultralytics import YOLO
model = YOLO("yolo11m.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt'...
# 100%|██████████| 38.8M/38.8M [20:24<00:00, 33.2kB/s]
