# %%
import cv2
from ultralytics import YOLO

# %%
model = YOLO('../../yolov11/yolo11n.pt')

cap = cv2.VideoCapture('test.mp4')

while True:
    ret, frame = cap.read()
    assert ret

    res = model.track(frame, conf=0.5, persist=True)

    res_plotted = res[0].plot()
    
    cv2.imshow('frame', res_plotted)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 2 dogs, 1 umbrella, 120.2ms
# Speed: 6.8ms preprocess, 120.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 190.7ms
# Speed: 31.7ms preprocess, 190.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 166.0ms
# Speed: 5.1ms preprocess, 166.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 177.8ms
# Speed: 11.3ms preprocess, 177.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 160.7ms
# Speed: 10.4ms preprocess, 160.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 168.3ms
# Speed: 7.5ms preprocess, 168.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 175.4ms
# Speed: 8.8ms preprocess, 175.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 193.7ms
# Speed: 17.2ms preprocess, 193.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 160.2ms
# Speed: 7.0ms preprocess, 160.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 152.5ms
# Speed: 9.0ms preprocess, 152.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 271.6ms
# Speed: 42.5ms preprocess, 271.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 143.4ms
# Speed: 14.1ms preprocess, 143.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 166.7ms
# Speed: 13.8ms preprocess, 166.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 133.4ms
# Speed: 10.6ms preprocess, 133.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 261.5ms
# Speed: 6.4ms preprocess, 261.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 107.5ms
# Speed: 8.4ms preprocess, 107.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 167.3ms
# Speed: 4.9ms preprocess, 167.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 171.5ms
# Speed: 7.2ms preprocess, 171.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 220.7ms
# Speed: 7.3ms preprocess, 220.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 145.0ms
# Speed: 5.6ms preprocess, 145.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 154.5ms
# Speed: 6.2ms preprocess, 154.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 135.3ms
# Speed: 8.7ms preprocess, 135.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 168.7ms
# Speed: 6.9ms preprocess, 168.7ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 136.6ms
# Speed: 8.8ms preprocess, 136.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 139.3ms
# Speed: 6.9ms preprocess, 139.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 218.2ms
# Speed: 10.2ms preprocess, 218.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 251.5ms
# Speed: 13.3ms preprocess, 251.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 137.6ms
# Speed: 13.7ms preprocess, 137.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 144.4ms
# Speed: 17.0ms preprocess, 144.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 130.9ms
# Speed: 7.3ms preprocess, 130.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 257.7ms
# Speed: 8.0ms preprocess, 257.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 134.1ms
# Speed: 8.1ms preprocess, 134.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 130.5ms
# Speed: 6.3ms preprocess, 130.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 135.5ms
# Speed: 8.9ms preprocess, 135.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 143.1ms
# Speed: 10.2ms preprocess, 143.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 134.4ms
# Speed: 7.3ms preprocess, 134.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 143.1ms
# Speed: 6.6ms preprocess, 143.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 139.1ms
# Speed: 7.8ms preprocess, 139.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 169.7ms
# Speed: 7.6ms preprocess, 169.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 dogs, 130.7ms
# Speed: 10.4ms preprocess, 130.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
