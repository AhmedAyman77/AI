# %%
from ultralytics import YOLO
import cv2
import cvzone
import math

# %%
model = YOLO("../../yolov11/yolo11n.pt")
print(model.names)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

# %%
video_path = "../../data/1.mp4"
cap = cv2.VideoCapture(video_path)

IDs = [1,2,3,5,7]

while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    results = model(frame, stream=True)

    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0] # for cv2
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            # cv2.rectangle(frame,(x1,y1),(x2,y2),(255,0,255),1)

            w, h = x2 - x1, y2 - y1 # for cvZone
            id = int(box.cls[0])
            conf = math.ceil(box.conf[0]*100) / 100

            if id in IDs and conf > 0.5:
                cvzone.cornerRect(frame, (x1, y1, w, h), l=9, rt=2, colorR=(255, 0, 255))
                # print(conf)
                cvzone.putTextRect(frame, f"{conf} {model.names[id]}", (max(0, x1), max(35, y1)), scale=1, thickness=1)

    cv2.imshow("YOLO", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 8 cars, 1 truck, 796.9ms
# Speed: 41.5ms preprocess, 796.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 1429.8ms
# Speed: 33.9ms preprocess, 1429.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 247.5ms
# Speed: 13.8ms preprocess, 247.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 269.2ms
# Speed: 33.8ms preprocess, 269.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 184.2ms
# Speed: 19.3ms preprocess, 184.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 191.9ms
# Speed: 6.3ms preprocess, 191.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 177.2ms
# Speed: 12.4ms preprocess, 177.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 167.2ms
# Speed: 13.4ms preprocess, 167.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 177.2ms
# Speed: 9.6ms preprocess, 177.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 169.8ms
# Speed: 8.0ms preprocess, 169.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 152.0ms
# Speed: 6.6ms preprocess, 152.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 1 chair, 148.3ms
# Speed: 6.4ms preprocess, 148.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 151.1ms
# Speed: 56.5ms preprocess, 151.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 161.1ms
# Speed: 7.0ms preprocess, 161.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 147.4ms
# Speed: 4.5ms preprocess, 147.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 128.1ms
# Speed: 6.6ms preprocess, 128.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 171.7ms
# Speed: 16.7ms preprocess, 171.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 136.5ms
# Speed: 15.4ms preprocess, 136.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 134.4ms
# Speed: 6.3ms preprocess, 134.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 212.9ms
# Speed: 10.8ms preprocess, 212.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 142.2ms
# Speed: 11.7ms preprocess, 142.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 133.0ms
# Speed: 4.5ms preprocess, 133.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 137.8ms
# Speed: 8.7ms preprocess, 137.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 153.7ms
# Speed: 4.2ms preprocess, 153.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 288.3ms
# Speed: 8.9ms preprocess, 288.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 140.2ms
# Speed: 6.2ms preprocess, 140.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 149.3ms
# Speed: 2.9ms preprocess, 149.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 126.0ms
# Speed: 5.9ms preprocess, 126.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 149.3ms
# Speed: 3.7ms preprocess, 149.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 147.5ms
# Speed: 9.8ms preprocess, 147.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 130.9ms
# Speed: 6.3ms preprocess, 130.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 148.5ms
# Speed: 5.1ms preprocess, 148.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 147.7ms
# Speed: 8.2ms preprocess, 147.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 136.5ms
# Speed: 7.4ms preprocess, 136.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 141.5ms
# Speed: 4.7ms preprocess, 141.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 172.5ms
# Speed: 5.2ms preprocess, 172.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 135.7ms
# Speed: 16.0ms preprocess, 135.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 150.5ms
# Speed: 4.6ms preprocess, 150.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 140.7ms
# Speed: 9.0ms preprocess, 140.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 142.1ms
# Speed: 7.1ms preprocess, 142.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 248.2ms
# Speed: 7.1ms preprocess, 248.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 136.1ms
# Speed: 10.6ms preprocess, 136.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 164.1ms
# Speed: 6.8ms preprocess, 164.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 153.0ms
# Speed: 8.1ms preprocess, 153.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 154.8ms
# Speed: 6.5ms preprocess, 154.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 135.8ms
# Speed: 8.7ms preprocess, 135.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 338.9ms
# Speed: 7.1ms preprocess, 338.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 168.2ms
# Speed: 9.3ms preprocess, 168.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 137.8ms
# Speed: 7.7ms preprocess, 137.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 139.1ms
# Speed: 8.4ms preprocess, 139.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 146.6ms
# Speed: 5.9ms preprocess, 146.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 144.4ms
# Speed: 10.1ms preprocess, 144.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 162.6ms
# Speed: 7.3ms preprocess, 162.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 151.6ms
# Speed: 4.4ms preprocess, 151.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 153.9ms
# Speed: 6.9ms preprocess, 153.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 155.2ms
# Speed: 7.5ms preprocess, 155.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 122.0ms
# Speed: 25.8ms preprocess, 122.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 143.5ms
# Speed: 34.2ms preprocess, 143.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 134.4ms
# Speed: 22.8ms preprocess, 134.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 1 truck, 163.9ms
# Speed: 4.8ms preprocess, 163.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 139.7ms
# Speed: 4.3ms preprocess, 139.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 136.1ms
# Speed: 7.4ms preprocess, 136.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 151.0ms
# Speed: 14.5ms preprocess, 151.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 187.7ms
# Speed: 8.1ms preprocess, 187.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 146.3ms
# Speed: 4.4ms preprocess, 146.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 132.9ms
# Speed: 5.5ms preprocess, 132.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 145.5ms
# Speed: 9.4ms preprocess, 145.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 347.0ms
# Speed: 21.7ms preprocess, 347.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 163.3ms
# Speed: 11.2ms preprocess, 163.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 156.8ms
# Speed: 6.1ms preprocess, 156.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 134.8ms
# Speed: 9.2ms preprocess, 134.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 267.1ms
# Speed: 13.9ms preprocess, 267.1ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 134.4ms
# Speed: 4.1ms preprocess, 134.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 242.7ms
# Speed: 8.1ms preprocess, 242.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 229.3ms
# Speed: 8.0ms preprocess, 229.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 135.4ms
# Speed: 8.5ms preprocess, 135.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 145.9ms
# Speed: 4.6ms preprocess, 145.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 149.6ms
# Speed: 7.3ms preprocess, 149.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 136.4ms
# Speed: 10.3ms preprocess, 136.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 141.2ms
# Speed: 27.4ms preprocess, 141.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 145.2ms
# Speed: 7.5ms preprocess, 145.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 162.9ms
# Speed: 6.3ms preprocess, 162.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 146.5ms
# Speed: 6.8ms preprocess, 146.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 134.7ms
# Speed: 6.7ms preprocess, 134.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 149.6ms
# Speed: 6.0ms preprocess, 149.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 144.4ms
# Speed: 4.9ms preprocess, 144.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 164.6ms
# Speed: 4.5ms preprocess, 164.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 141.3ms
# Speed: 21.4ms preprocess, 141.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 144.4ms
# Speed: 7.6ms preprocess, 144.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 267.4ms
# Speed: 7.2ms preprocess, 267.4ms inference, 20.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 166.8ms
# Speed: 27.9ms preprocess, 166.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 179.7ms
# Speed: 33.2ms preprocess, 179.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 168.8ms
# Speed: 4.1ms preprocess, 168.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 151.5ms
# Speed: 6.9ms preprocess, 151.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 135.8ms
# Speed: 5.0ms preprocess, 135.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 137.1ms
# Speed: 10.3ms preprocess, 137.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 truck, 152.8ms
# Speed: 8.3ms preprocess, 152.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 153.2ms
# Speed: 4.4ms preprocess, 153.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
