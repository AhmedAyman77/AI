# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !scp '/content/drive/MyDrive/Fashion_MNIST/Fashion_MNIST_Dataset.zip' '/content/data.zip'
# !unzip '/content/data.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10056.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10072.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10130.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10345.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10392.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10394.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10444.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10557.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/1060.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10644.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10736.png
#   inflating: /content/Fashion_MNIST_Dataset/train/Ankle boot/10738.png
# ...

# %%
# !pip install ultralytics

# %%
import os
from ultralytics import YOLO

model = YOLO("yolov8n-cls.pt")
results = model.train(data='/content/Fashion_MNIST_Dataset/', epochs=5)
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs/ '/content/drive/MyDrive/Fashion_MNIST'
